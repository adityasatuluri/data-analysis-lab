# %% [markdown]
# LINK:
# https://eduxir.com/study-material/ncert-solutions/class-11/information-practices/introduction-to-numpy/case-study-solutions/

# %%
import numpy as np
import pandas as pd

# %%
#1.
iris = pd.read_csv('iris1.csv', delimiter=',', dtype=None, header=None)
species_dict = {'Iris-setosa': 1, 'Iris-versicolor': 2, 'Iris-virginica': 3}
iris[5] = iris[4].map(species_dict)  # iris[5]:result_column iris[4]:dependant_column
iris
# Out:
#        0    1    2    3               4  5
# 0    5.1  3.5  1.4  0.2     Iris-setosa  1
# 1    4.9  3.0  1.4  0.2     Iris-setosa  1
# 2    4.7  3.2  1.3  0.2     Iris-setosa  1
# 3    4.6  3.1  1.5  0.2     Iris-setosa  1
# 4    5.0  3.6  1.4  0.2     Iris-setosa  1
# ..   ...  ...  ...  ...             ... ..
# 145  6.7  3.0  5.2  2.3  Iris-virginica  3
# 146  6.3  2.5  5.0  1.9  Iris-virginica  3
# 147  6.5  3.0  5.2  2.0  Iris-virginica  3
# 148  6.2  3.4  5.4  2.3  Iris-virginica  3
# 149  5.9  3.0  5.1  1.8  Iris-virginica  3
#
# [150 rows x 6 columns]

# %%
#2. Dropping column whose index=4 from array iris
iris=iris.drop([4],axis=1)

# %%
#3.print shape, dimensions and size
print(iris.shape)
print(iris.size)
print(iris.ndim)
# Out:
# (150, 5)
# 750
# 2

# %%
#4. Splitting iris into 2d arrays
iris_arr=iris.to_numpy()
iris_arr = np.split(iris_arr, 3)
iris1=iris_arr[0]
iris2=iris_arr[1]
iris3=iris_arr[2]

#5. Print the arrays
print(iris1,'\n\n',iris2,'\n\n',iris3)
# Out:
# [[5.1 3.5 1.4 0.2 1. ]
#  [4.9 3.  1.4 0.2 1. ]
#  [4.7 3.2 1.3 0.2 1. ]
#  [4.6 3.1 1.5 0.2 1. ]
#  [5.  3.6 1.4 0.2 1. ]
#  [5.4 3.9 1.7 0.4 1. ]
#  [4.6 3.4 1.4 0.3 1. ]
#  [5.  3.4 1.5 0.2 1. ]
#  [4.4 2.9 1.4 0.2 1. ]
#  [4.9 3.1 1.5 0.1 1. ]
#  [5.4 3.7 1.5 0.2 1. ]
#  [4.8 3.4 1.6 0.2 1. ]
#  [4.8 3.  1.4 0.1 1. ]
#  [4.3 3.  1.1 0.1 1. ]
#  [5.8 4.  1.2 0.2 1. ]
#  [5.7 4.4 1.5 0.4 1. ]
#  [5.4 3.9 1.3 0.4 1. ]
#  [5.1 3.5 1.4 0.3 1. ]
#  [5.7 3.8 1.7 0.3 1. ]
#  [5.1 3.8 1.5 0.3 1. ]
#  [5.4 3.4 1.7 0.2 1. ]
#  [5.1 3.7 1.5 0.4 1. ]
#  [4.6 3.6 1.  0.2 1. ]
#  [5.1 3.3 1.7 0.5 1. ]
#  [4.8 3.4 1.9 0.2 1. ]
#  [5.  3.  1.6 0.2 1. ]
#  [5.  3.4 1.6 0.4 1. ]
#  [5.2 3.5 1.5 0.2 1. ]
#  [5.2 3.4 1.4 0.2 1. ]
#  [4.7 3.2 1.6 0.2 1. ]
#  [4.8 3.1 1.6 0.2 1. ]
#  [5.4 3.4 1.5 0.4 1. ]
#  [5.2 4.1 1.5 0.1 1. ]
#  [5.5 4.2 1.4 0.2 1. ]
#  [4.9 3.1 1.5 0.1 1. ]
#  [5.  3.2 1.2 0.2 1. ]
#  [5.5 3.5 1.3 0.2 1. ]
#  [4.9 3.1 1.5 0.1 1. ]
#  [4.4 3.  1.3 0.2 1. ]
#  [5.1 3.4 1.5 0.2 1. ]
#  [5.  3.5 1.3 0.3 1. ]
#  [4.5 2.3 1.3 0.3 1. ]
#  [4.4 3.2 1.3 0.2 1. ]
#  [5.  3.5 1.6 0.6 1. ]
#  [5.1 3.8 1.9 0.4 1. ]
#  [4.8 3.  1.4 0.3 1. ]
#  [5.1 3.8 1.6 0.2 1. ]
#  [4.6 3.2 1.4 0.2 1. ]
#  [5.3 3.7 1.5 0.2 1. ]
#  [5.  3.3 1.4 0.2 1. ]]
#
#  [[7.  3.2 4.7 1.4 2. ]
#  [6.4 3.2 4.5 1.5 2. ]
#  [6.9 3.1 4.9 1.5 2. ]
#  [5.5 2.3 4.  1.3 2. ]
#  [6.5 2.8 4.6 1.5 2. ]
#  [5.7 2.8 4.5 1.3 2. ]
#  [6.3 3.3 4.7 1.6 2. ]
#  [4.9 2.4 3.3 1.  2. ]
#  [6.6 2.9 4.6 1.3 2. ]
#  [5.2 2.7 3.9 1.4 2. ]
#  [5.  2.  3.5 1.  2. ]
#  [5.9 3.  4.2 1.5 2. ]
#  [6.  2.2 4.  1.  2. ]
#  [6.1 2.9 4.7 1.4 2. ]
#  [5.6 2.9 3.6 1.3 2. ]
#  [6.7 3.1 4.4 1.4 2. ]
#  [5.6 3.  4.5 1.5 2. ]
#  [5.8 2.7 4.1 1.  2. ]
#  [6.2 2.2 4.5 1.5 2. ]
#  [5.6 2.5 3.9 1.1 2. ]
#  [5.9 3.2 4.8 1.8 2. ]
#  [6.1 2.8 4.  1.3 2. ]
#  [6.3 2.5 4.9 1.5 2. ]
#  [6.1 2.8 4.7 1.2 2. ]
#  [6.4 2.9 4.3 1.3 2. ]
#  [6.6 3.  4.4 1.4 2. ]
#  [6.8 2.8 4.8 1.4 2. ]
#  [6.7 3.  5.  1.7 2. ]
#  [6.  2.9 4.5 1.5 2. ]
#  [5.7 2.6 3.5 1.  2. ]
#  [5.5 2.4 3.8 1.1 2. ]
#  [5.5 2.4 3.7 1.  2. ]
#  [5.8 2.7 3.9 1.2 2. ]
#  [6.  2.7 5.1 1.6 2. ]
#  [5.4 3.  4.5 1.5 2. ]
#  [6.  3.4 4.5 1.6 2. ]
#  [6.7 3.1 4.7 1.5 2. ]
#  [6.3 2.3 4.4 1.3 2. ]
#  [5.6 3.  4.1 1.3 2. ]
#  [5.5 2.5 4.  1.3 2. ]
#  [5.5 2.6 4.4 1.2 2. ]
#  [6.1 3.  4.6 1.4 2. ]
#  [5.8 2.6 4.  1.2 2. ]
#  [5.  2.3 3.3 1.  2. ]
#  [5.6 2.7 4.2 1.3 2. ]
#  [5.7 3.  4.2 1.2 2. ]
#  [5.7 2.9 4.2 1.3 2. ]
#  [6.2 2.9 4.3 1.3 2. ]
#  [5.1 2.5 3.  1.1 2. ]
#  [5.7 2.8 4.1 1.3 2. ]]
#
#  [[6.3 3.3 6.  2.5 3. ]
#  [5.8 2.7 5.1 1.9 3. ]
#  [7.1 3.  5.9 2.1 3. ]
#  [6.3 2.9 5.6 1.8 3. ]
#  [6.5 3.  5.8 2.2 3. ]
#  [7.6 3.  6.6 2.1 3. ]
#  [4.9 2.5 4.5 1.7 3. ]
#  [7.3 2.9 6.3 1.8 3. ]
#  [6.7 2.5 5.8 1.8 3. ]
#  [7.2 3.6 6.1 2.5 3. ]
#  [6.5 3.2 5.1 2.  3. ]
#  [6.4 2.7 5.3 1.9 3. ]
#  [6.8 3.  5.5 2.1 3. ]
#  [5.7 2.5 5.  2.  3. ]
#  [5.8 2.8 5.1 2.4 3. ]
#  [6.4 3.2 5.3 2.3 3. ]
#  [6.5 3.  5.5 1.8 3. ]
#  [7.7 3.8 6.7 2.2 3. ]
#  [7.7 2.6 6.9 2.3 3. ]
#  [6.  2.2 5.  1.5 3. ]
#  [6.9 3.2 5.7 2.3 3. ]
#  [5.6 2.8 4.9 2.  3. ]
#  [7.7 2.8 6.7 2.  3. ]
#  [6.3 2.7 4.9 1.8 3. ]
#  [6.7 3.3 5.7 2.1 3. ]
#  [7.2 3.2 6.  1.8 3. ]
#  [6.2 2.8 4.8 1.8 3. ]
#  [6.1 3.  4.9 1.8 3. ]
#  [6.4 2.8 5.6 2.1 3. ]
#  [7.2 3.  5.8 1.6 3. ]
#  [7.4 2.8 6.1 1.9 3. ]
#  [7.9 3.8 6.4 2.  3. ]
#  [6.4 2.8 5.6 2.2 3. ]
#  [6.3 2.8 5.1 1.5 3. ]
#  [6.1 2.6 5.6 1.4 3. ]
#  [7.7 3.  6.1 2.3 3. ]
#  [6.3 3.4 5.6 2.4 3. ]
#  [6.4 3.1 5.5 1.8 3. ]
#  [6.  3.  4.8 1.8 3. ]
#  [6.9 3.1 5.4 2.1 3. ]
#  [6.7 3.1 5.6 2.4 3. ]
#  [6.9 3.1 5.1 2.3 3. ]
#  [5.8 2.7 5.1 1.9 3. ]
#  [6.8 3.2 5.9 2.3 3. ]
#  [6.7 3.3 5.7 2.5 3. ]
#  [6.7 3.  5.2 2.3 3. ]
#  [6.3 2.5 5.  1.9 3. ]
#  [6.5 3.  5.2 2.  3. ]
#  [6.2 3.4 5.4 2.3 3. ]
#  [5.9 3.  5.1 1.8 3. ]]

# %%
#6.
header=np.array(["sepal length","sepal width","petal length","petal width","species No"])
#7.
print(header)
# Out:
# ['sepal length' 'sepal width' 'petal length' 'petal width' 'species No']

# %%
#8.
iris_max=iris.max(axis=0).round(2)
iris_min=iris.min(axis=0).round(2)
iris_mean=iris.mean(axis=0).round(2)
iris_std=iris.std(axis=0).round(2)
iris_max=iris.max(axis=0).round(2)
